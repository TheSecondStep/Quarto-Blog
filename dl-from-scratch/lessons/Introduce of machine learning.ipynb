# %% [markdown]
# ---
# title: "机器学习介绍"
# author: "逃之夭夭"
# date: "2026-04-16"
# categories: [机器学习]
# image: "images/introduce.jpg"
# ---

# %% [markdown]
# > 机器学习是这样一个领域：它赋予计算机无需显式编程即可学习的能力。——阿瑟·塞缪尔

# %% [markdown]
# # 人工智能、机器学习和深度学习

# %% [markdown]
# ![what_is_ml](images/what_is_ml.jpg){width="50%"}

# %% [markdown]
# # 什么是机器学习

# %% [markdown]
# ![02](images/02.jpg){width="50%"}

# %% [markdown]
# # Learning Map

# %% [markdown]
# ![lm](images/learning_map.jpg)

# %% [markdown]
# ![01_regression](images/01_regression.jpg)
