# %% [markdown]
# ---
# title: "人工智能介绍"
# author: "逃之夭夭"
# date: "2026-04-16"
# categories: [机器学习]
# image: "images/introduce.jpg"
# ---

# %% [markdown]
# > 机器学习是这样一个领域：它赋予计算机无需显式编程即可学习的能力。——阿瑟·塞缪尔

# %% [markdown]
# # 人工智能、机器学习和深度学习

# %% [markdown]
# ```{mermaid}
#   flowchart TB
#       AI["**人工智能 AI**<br>让机器表现出智能"]
#       ML["**机器学习 ML**<br>从数据中学习规律"]
#       DL["**深度学习 DL**<br>多层神经网络自动提取特征"]
#
#       AI --> ML --> DL
#
#       AI --- A1["符号推理 · 专家系统"]
#       ML --- M1["SVM · 随机森林 · KNN"]
#       DL --- D1["CNN · RNN · Transformer"]
#
#       style AI fill:#d4e6f1,stroke:#2c3e50,stroke-width:2px
#       style ML fill:#a9dfbf,stroke:#27ae60,stroke-width:2px
#       style DL fill:#f9e79f,stroke:#f39c12,stroke-width:2px
#       style A1 fill:#eaf2f8,stroke:none
#       style M1 fill:#eafaf1,stroke:none
#       style D1 fill:#fef9e7,stroke:none
#   ```

# %% [markdown]
# # 什么是机器学习
